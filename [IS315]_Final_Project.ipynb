# %% [markdown]
# <a href="https://colab.research.google.com/github/kelsingo/Molecular-Dynamics-of-Lipid-Raft-Boundary-Regulation/blob/main/%5BIS315%5D_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RDF

# %%
import matplotlib.pyplot as plt

# %%
rdf_files = [
    ('rdf_DIPC_POP2.xvg', 'DIPC-POP2'),
    ('rdf_CHOL_POP2.xvg', 'CHOL-POP2'),
    ('rdf_DPPC_POP2.xvg', 'DPPC-POP2')
]

for filename, label in rdf_files:
    r, g = [], []
    with open(filename) as f:
        for line in f:
            if line.startswith(('#', '@')):
                continue
            parts = line.split()
            r.append(float(parts[0]))
            g.append(float(parts[1]))
    plt.plot(r, g, label=label)

plt.xlabel('r (nm)')
plt.ylabel('g(r)')
plt.title('Radial Distribution Functions')
plt.legend()
plt.show()

# %% [markdown]
# # MSD

# %%
msd_files = [
    ('msd_CHOL.xvg', 'CHOL'),
    ('msd_DIPC.xvg', 'DIPC'),
    ('msd_DPPC.xvg', 'DPPC'),
    ('msd_PIP2.xvg', 'PIP2')
]

for filename, label in msd_files:
  ts, msd = [], []
  with open(filename) as f:
    for line in f:
      if line.startswith(('#', '@')):
        continue

      parts = line.split()
      ts.append(float(parts[0]))
      msd.append(float(parts[1]))


  plt.plot(ts, msd, label=label)

plt.xlabel('Time steps')
plt.ylabel('MSD $\mathrm{nm^2}$', fontsize = 12)
plt.title('Mean Square Displacement')
plt.legend()
plt.savefig('name', dpi = 300)
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\m'
# <>:23: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipython-input-1875111723.py:23: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('MSD $\mathrm{nm^2}$', fontsize = 12)
